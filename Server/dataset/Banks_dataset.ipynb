# %% [markdown]
# # config

# %% [markdown]
# ### Structure

# %%
types = ["personnel", "professionnel", "entreprise"]

# %% [markdown]
# ### template

# %%
template = {
    
    "personnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "",
          "tenue_compte_cheque": "",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "",
          "virement_hors_agence": "",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "",
          "retrait_intra_bancaire": "",
          "retrait_inter_bancaire": "",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "professionnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "",
          "tenue_compte_cheque": "",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "",
          "virement_hors_agence": "",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "",
          "retrait_intra_bancaire": "",
          "retrait_inter_bancaire": "",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "entreprise": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "",
          "tenue_compte_cheque": "",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "",
          "virement_hors_agence": "",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "",
          "retrait_intra_bancaire": "",
          "retrait_inter_bancaire": "",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    }
}

# %% [markdown]
# # bank_names

# %%
banks = {
          "BANQUE NATIONALE D ALGERIE - BNA": template, #done
          "BANQUE DE L AGRICULTURE ET DU DEVELOPPEMENT RURAL - BADR": template, #done
          "BANQUE DE DEVELOPPEMENT LOCAL - BDL": template, #done
          "CREDIT POPULAIRE D ALGERIE - CPA": template, #done
          "ARAB BANKING CORPORATION ALGERIE - ABC": template, #done
          "NATIXIS BANQUE": template, #done
          "SOCIETE GENERALE ALGERIE": template,
          "ARAB BANK PLC ALGERIA": template, #done
          "B.N.P.-PARIBAS EL DJAZAIR": template,
          "TRUST BANK ALGERIA": template,
          "GULF BANK ALGERIA": template,
          "THE HOUSING BANK FOR TRADE AND FINANCE-ALGERIA": template,
          "FRANSABANK EL-DJAZAIR": template,
          "CREDIT AGRICOLE CORPORATE ET INVESTISSEMENT BANK - ALGERIE": template,
          "AL SALAM BANK - ALGERIA - SPA": template, #done
         }

# %% [markdown]
# # banks

# %% [markdown]
# ## bna

# %%
banks["BANQUE NATIONALE D ALGERIE - BNA"] = {
    "personnel": {
        "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "200 DA/AN",
          "ouverture_compte_epargne": "2,50%",
          "tenue_compte_epargne": "50 DA/AN",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "Taux et conditions fixés par la Banque d'Algérie",
          "fermeture_de_compte": "200 DA"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "5 DA /opération",
          "e_banking_virement": "gratuit",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "60 DA",
          "sms_banking_virement_en_agence": "10 DA /opération",
          "sms_banking_virement_hors_agence": "10 DA /opération",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "0,5‰",
          "virement_en_agence": "20 DA",
          "virement_hors_agence": "30 DA",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "Gratuit",
          "retraits_hors_agence": "0,5‰",
          "payment_cheque_en_agence": "Gratuit",
          "payment_cheque_hors_agence": "≤ 50000 DA Gratuit, > 50000 DA 50 DA+ frais de transmission de l'image du cheque",
          "vente_devise": "2‰ Min 300 DA",
          "achat_devise": "Gratuit"
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "Classique/ Gold/ Epargne 150 DA/ 200 DA/ 150 DA",
          "retrait_intra_bancaire": "20 DA HT",
          "retrait_inter_bancaire": "35 DA TTC",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "Moins de 500 000 DA Taux en vigeur",
          "epargne_duree_taux_02": "De 500 001 à 2 500 000 DA 3%",
          "epargne_duree_taux_03": "De 2 500 001 DA à 7 500 000 DA 3.25%",
          "epargne_duree_taux_04": "De 7 500 001 DA à 15 000 000 DA 3.5%",
          "epargne_duree_taux_05": "De 15 000 001 DA à 50 000 000 DA 3.75%",
          "epargne_duree_taux_06": "De 50 000 001 DA à 100 000 000 DA 4%",
          "epargne_duree_taux_07": "De 100 000 001 DA à 200 000 000 DA 4.25%",
          "epargne_duree_taux_08": "Plus de 200 000 000 DA 4.5%",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "5000 DA/ AN",
          "moyen": "7000 DA/ AN",
          "grand": "10000 DA/ AN",
          "cautionnement": "20000 DA"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "500 DA /Appoint + frais du correspondant",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },
    },

    #################################################################################

    "professionnel":{
            "gestion_de_compte": {
        "ouverture_compte_courant": "Gratuit",
        "tenue_compte_courant": "",

        "ouverture_compte_cheque": "Gratuit",
        "tenue_compte_cheque": "200 DA/AN",
        "ouverture_compte_epargne": "",
        "tenue_compte_epargne": "50 DA/AN",
        "ouverture_compte_devise": "",
        "tenue_compte_devise": "taux et conditions fixés par la Banque d'Algérie",
        "fermeture_de_compte": "200 DA"
    },

    "gestion_a_distance": {
        "e_banking_abonnement": "800 DA / Mois",
        "e_banking_consultation_solde": "",
        "e_banking_virement": "10 DA /opération",
        "e_banking_paiment": "",
        "sms_banking_abonnement": "18 DA",
        "sms_banking_virement_en_agence": "",
        "sms_banking_virement_hors_agence": "",
        "service_contact": "",
    },

    "option_de_payment": {
        "versement_en_agence": "Gratuit",
        "versement_hors_agence": "0,5‰",
        "virement_en_agence": "Gratuit",
        "virement_hors_agence": "20 DA",
        "prelevement_en_agence": "",
        "prelevement_hors_agence": "",
        "retraits_en_agence": "Gratuit",
        "retraits_hors_agence": "0,5‰",
        "payment_cheque_en_agence": "Gratuit",
        "payment_cheque_hors_agence": "≤ 50000 DA Gratuit, > 50000 DA 50 DA+ frais de transmission de l'image du cheque",
        "vente_devise": "2‰ Min 300 DA",
        "achat_devise": "Gratuit"
    },

    "moyens_de_payment": {
        "creation_bank_card": "Gratuit",
        "renouvelement_bank_card": "Gratuit",
        "remplacement_bank_card": "",
        "edition_code_confidentiel_bank_card": " Classique/ Gold 150/ 200 DA",
        "retrait_intra_bancaire": "20 DA HT",
        "retrait_inter_bancaire": "35 DA TTC",
        "creation_visa": "",
        "renouvelement_visa": "",
        "remplacement_visa": "",
        "edition_code_confidentiel_visa": "",
    },

    "prets_et_credits": {
        "decouvert_duree": "< 24 mois",
        "decouvert_taux": "8,50%",
        "credit_court_terme_taux": "",
        "credit_moyen_terme_taux": "5,25%",
        "credit_long_terme_taux": "5,50%",
        "options_possibles": "Industrie, Agriculture, Pêche, Tourisme, NTIC et numériques"
    },

    "placement": {
        "depots_a_court_terme": "DE 1 à 1,15%",
        "depots_a_moyen_terme": "",
        "depots_a_long_terme": "",
    },

    "epargne": {
        "epargne_duree_taux_01": "",
        "epargne_duree_taux_02": "",
        "epargne_duree_taux_03": "",
        "epargne_duree_taux_04": "",
        "epargne_duree_taux_05": "",
        "epargne_duree_taux_06": "",
        "epargne_duree_taux_07": "",
        "epargne_duree_taux_08": "",
        "epargne_duree_taux_09": "",
        "epargne_duree_taux_10": "",
    },

    "coffre_fort": {
        "petit": "5000 DA/ AN",
        "moyen": "7000 DA/ AN",
        "grand": "10000 DA/ AN",
        "cautionnement": "20000DA"
    },

    "financement_externe": {
        "encaissement_cheque_etranger": "",
        "virement_recu": "",
        "virement_emis": "",
        "exportation_domiciliation": "1000 DA/ dossier",
        "importation_domiciliation": "2 000 DA/ dossier",
        "transfert_libre_prelevement_compte_dinars": "1,50‰ avec min 2500 DA+ frais SWIFT 1000DA+ commission de change BA1‰",
        "transfert_libre_prelevement_compte_devise": "1,50‰ avec min 2500 DA+ frais SWIFT 1000 DA",
    },
    },

    ############################""

    "entreprise":{
        
    "gestion_de_compte": {
        "ouverture_compte_courant": "Gratuit",
        "tenue_compte_courant": "2500 DA/An",
        "ouverture_compte_cheque": "",
        "tenue_compte_cheque": "",
        "ouverture_compte_epargne": "",
        "tenue_compte_epargne": "",
        "ouverture_compte_devise": "Gratuit",
        "tenue_compte_devise": "",
        "fermeture_de_compte": "2500 DA"
    },

    "gestion_a_distance": {
        "e_banking_abonnement": "800 DA / Mois (Deuxième compte est facturé à 50%)",
        "e_banking_consultation_solde": "",
        "e_banking_virement": "10 DA /opération",
        "e_banking_paiment": "10 DA HT",
        "sms_banking_abonnement": "18 DA",
        "sms_banking_virement_en_agence": "",
        "sms_banking_virement_hors_agence": "",
        "service_contact": "",
    },

    "option_de_payment": {
        "versement_en_agence": "Gratuit",
        "versement_hors_agence": "0,5‰",
        "virement_en_agence": "Gratuit",
        "virement_hors_agence": "20 DA",
        "prelevement_en_agence": "",
        "prelevement_hors_agence": "",
        "retraits_en_agence": "Gratuit",
        "retraits_hors_agence": "0,5‰",
        "payment_cheque_en_agence": "Gratuit",
        "payment_cheque_hors_agence": "Gratuit",
        "vente_devise": "2‰ Min 300 DA",
        "achat_devise": "Gratuit"
    },

    "moyens_de_payment": {
        "creation_bank_card": "Gratuit",
        "renouvelement_bank_card": "Gratuit",
        "remplacement_bank_card": "",
        "edition_code_confidentiel_bank_card": "Classique/ Gold 150/ 200 DA",
        "retrait_intra_bancaire": "20 DA HT",
        "retrait_inter_bancaire": "35 DA TTC",
        "creation_visa": "",
        "renouvelement_visa": "",
        "remplacement_visa": "",
        "edition_code_confidentiel_visa": "",
    },

    "prets_et_credits": {
        "decouvert_duree": "< 24 mois ",
        "decouvert_taux": "8,50%",
        "credit_court_terme_taux": "",
        "credit_moyen_terme_taux": "5,25%",
        "credit_long_terme_taux": "5,50%",
        "options_possibles": "Industrie, Agriculture, Pêche, Tourisme, NTIC et numériques"
    },

    "placement": {
        "depots_a_court_terme": "30 à 89 jours DE 1 à 1,15%",
        "depots_a_moyen_terme": "",
        "depots_a_long_terme": "",
    },

    "epargne": {
        "epargne_duree_taux_01": "",
        "epargne_duree_taux_02": "",
        "epargne_duree_taux_03": "",
        "epargne_duree_taux_04": "",
        "epargne_duree_taux_05": "",
        "epargne_duree_taux_06": "",
        "epargne_duree_taux_07": "",
        "epargne_duree_taux_08": "",
        "epargne_duree_taux_09": "",
        "epargne_duree_taux_10": "",
    },

    "coffre_fort": {
        "petit": "5000 DA/ AN",
        "moyen": "7000 DA/ AN",
        "grand": "10000 DA/ AN",
        "cautionnement": "20000DA"
    },

    "financement_externe": {
        "encaissement_cheque_etranger": "Gratuit",
        "virement_recu": "",
        "virement_emis": "",
        "exportation_domiciliation": "1000 DA/ dossier",
        "importation_domiciliation": "2 000 DA/ dossier",
        "transfert_libre_prelevement_compte_dinars": "1,50‰ avec min 2500 DA+ frais SWIFT 1000DA+ commission de change BA1‰",
        "transfert_libre_prelevement_compte_devise": "1,50‰ avec min 2500 DA+ frais SWIFT 1000 DA",
    },
    }
}

# %% [markdown]
# ## badr

# %%
banks["BANQUE DE L AGRICULTURE ET DU DEVELOPPEMENT RURAL - BADR"] = {
    
    "personnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "1000 DA/trim",
          "tenue_compte_cheque": "",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "Gratuit",
          "e_banking_consultation_solde": "Gratuit",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "emis 300 DA, recu gratuit",
          "virement_hors_agence": "emis 300 DA, recu gratuit",
          "prelevement_en_agence": "Gratuit",
          "prelevement_hors_agence": "150 DA",
          "retraits_en_agence": "",
          "retraits_hors_agence": "0.5‰, minimum 100 DA, plafonné a 500000 DA",
          "payment_cheque_en_agence": "< 50000 10DA, < 5000000 200DA, > 5000000 0.25‰",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "",
          "retrait_intra_bancaire": "15 DA",
          "retrait_inter_bancaire": "29.41 DA",
          "creation_visa": "titanium 17000 DA, classique 12000 DA/ 2 ans",
          "renouvelement_visa": "titanium 5000 DA, classique 3000 DA ",
          "remplacement_visa": "17000 DA, classique 12000 DA/ 2 ans",
          "edition_code_confidentiel_visa": "500 DA",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "8000 DA/an",
          "moyen": "12000 DA/an",
          "grand": "16000 DA/an",
          "cautionnement": "10000 DA/an"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "0.25% + 0.1% commission BA, min 2500 DA + Frais de Swift 3500 DA",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "professionnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "",
          "tenue_compte_cheque": "",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "",
          "virement_hors_agence": "",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "",
          "retrait_intra_bancaire": "",
          "retrait_inter_bancaire": "",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "entreprise": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "3000 DA/an",
          "ouverture_compte_cheque": "1000 DA/trim",
          "tenue_compte_cheque": "",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "emis 300 DA, recu gratuit",
          "virement_hors_agence": "emis 300 DA, recu gratuit",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "0.5‰, minimum 100 DA, plafonné a 500000 DA",
          "payment_cheque_en_agence": "Gratuit",
          "payment_cheque_hors_agence": "< 50000 10DA, < 5000000 200DA, > 5000000 0.25‰",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "",
          "retrait_intra_bancaire": "15 DA",
          "retrait_inter_bancaire": "29.41 DA",
          "creation_visa": "titanium 17000 DA, classique 12000 DA/ 2 ans",
          "renouvelement_visa": "titanium 5000 DA, classique 3000 DA ",
          "remplacement_visa": "17000 DA, classique 12000 DA/ 2 ans",
          "edition_code_confidentiel_visa": "500 DA",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "< 10000000 5000 DA, >=10000000 10000 DA",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "8000 DA/an",
          "moyen": "12000 DA/an",
          "grand": "16000 DA/an",
          "cautionnement": "10000 DA/an"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "3000 DA",
          "importation_domiciliation": "3000 DA",
          "transfert_libre_prelevement_compte_dinars": "0.25% + 0.1% commission BA, min 2500 DA + Frais de Swift 3500 DA",
          "transfert_libre_prelevement_compte_devise": "",
      },       
    }
}

# %% [markdown]
# ## bdl

# %%
banks["BANQUE DE DEVELOPPEMENT LOCAL - BDL"] = {
    
    "personnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "500 DA/An",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "500 DA/An",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "500 DA/An",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "150 DA",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "Gratuit",
          "retraits_hors_agence": "400 DA",
          "payment_cheque_en_agence": "Gratuit",
          "payment_cheque_hors_agence": "Gratuit",
          "vente_devise": "0,25% min 300DA",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "classique gratuit, gold gratuit",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "classique 400da, gold 800da",
          "edition_code_confidentiel_bank_card": "classique 200, gold 300",
          "retrait_intra_bancaire": "20 da",
          "retrait_inter_bancaire": "35 da",
          "creation_visa": "classique 2000 DA, gold 5000 DA, platinium 14000 DA",
          "renouvelement_visa": "classique 2000 DA, gold 5000 DA, platinium 14000 DA",
          "remplacement_visa": "classique 2000 DA, gold 5000 DA, platinium 14000 DA",
          "edition_code_confidentiel_visa": "500da, platinium 1000 DA",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": "voitures, equipements"
      },

      "placement": {
          "depots_a_court_terme": "03 à 06 mois 2% / 07 à 12 mois 2,25% / 13 à 24 mois 2,50",
          "depots_a_moyen_terme": "25 à 36 mois 2,75% / 37 à 42 mois 3,25% / 43 à 48 mois 3,50%",
          "depots_a_long_terme": "49 à 54 mois 3,75% / 55 à 60 mois 4,25%",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "5000",
          "moyen": "7000",
          "grand": "10000",
          "cautionnement": "10000"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "professionnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "2000 DA/An",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "2000 DA/An",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "50 DA, autre banque 200 DA",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "Gratuit",
          "retraits_hors_agence": "400 DA",
          "payment_cheque_en_agence": "Gratuit",
          "payment_cheque_hors_agence": "Gratuit",
          "vente_devise": "0,25% min 300DA",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "classique gratuit, gold gratuit",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "classique 400da, gold 800da",
          "edition_code_confidentiel_bank_card": "classique 200, gold 300",
          "retrait_intra_bancaire": "20 da",
          "retrait_inter_bancaire": "35 da",
          "creation_visa": "classique 2000 DA, gold 5000 DA, platinium 14000 DA",
          "renouvelement_visa": "classique 2000 DA, gold 5000 DA, platinium 14000 DA",
          "remplacement_visa": "classique 2000 DA, gold 5000 DA, platinium 14000 DA",
          "edition_code_confidentiel_visa": "500da, platinium 1000 DA",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "03 à 06 mois 2% / 07 à 12 mois 2,25% / 13 à 24 mois 2,50",
          "depots_a_moyen_terme": "25 à 36 mois 2,75% / 37 à 42 mois 3,25% / 43 à 48 mois 3,50%",
          "depots_a_long_terme": "49 à 54 mois 3,75% / 55 à 60 mois 4,25%",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "1000",
          "importation_domiciliation": "3000",
          "transfert_libre_prelevement_compte_dinars": "0,25% min: 2 000 DA",
          "transfert_libre_prelevement_compte_devise": "0,25% min: 2 000 DA",
      },        
    },

    #####################################################################

    "entreprise": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "2500 DA/An",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "2500 DA/An",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "50 DA, autre banque 200 DA",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "Gratuit",
          "retraits_hors_agence": "400 DA",
          "payment_cheque_en_agence": "Gratuit",
          "payment_cheque_hors_agence": "Gratuit",
          "vente_devise": "0,25% min 300DA",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "",
          "retrait_intra_bancaire": "",
          "retrait_inter_bancaire": "",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "03 à 06 mois 2% / 07 à 12 mois 2,25% / 13 à 24 mois 2,50",
          "depots_a_moyen_terme": "25 à 36 mois 2,75% / 37 à 42 mois 3,25% / 43 à 48 mois 3,50%",
          "depots_a_long_terme": "49 à 54 mois 3,75% / 55 à 60 mois 4,25%",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "3000",
          "importation_domiciliation": "3000",
          "transfert_libre_prelevement_compte_dinars": "0,25% min: 2 000 DA",
          "transfert_libre_prelevement_compte_devise": "0,25% min: 2 000 DA",
      },        
    }
}

# %% [markdown]
# ## salam

# %%
banks["AL SALAM BANK - ALGERIA - SPA"] = {
    
    "personnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "2 500,00 /Trim",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "1 000,00 an",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit",
          "ouverture_compte_devise": "Gratuit",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "gratuit",
          "e_banking_consultation_solde": "Gratuit",
          "e_banking_virement": "Gratuit",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "100,00",
          "prelevement_en_agence": "Gratuit",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "classique 450,00, premium 550,00, gold 650,00 / an",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "200",
          "retrait_intra_bancaire": "20",
          "retrait_inter_bancaire": "29.41",
          "creation_visa": "prepaye 2000,00, classique 4000,00, gold 6500,00, platinium 14000,00 / an",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "1000",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "03 mois client:25% banque : 75%, 06 mois client:45% banque : 55%, 12 mois client:59% banque : 41%",
          "depots_a_moyen_terme": "18 mois client:62% banque : 38%, 24 mois client:65% banque : 35%, 36 mois client:72% banque : 28%",
          "depots_a_long_terme": "48 mois client:80% banque : 20%, >=60 mois client:91% banque : 9%",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "5 000,00 / an",
          "moyen": "8 000,00 / an",
          "grand": "10 000,00 / an",
          "cautionnement": "10 000,00 / an"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "4 000,00 DA",
          "importation_domiciliation": "3 000,00 DA",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "professionnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "2 500,00 /Trim",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "1 000,00 /an",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit",
          "ouverture_compte_devise": "Gratuit",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "gratuit",
          "e_banking_consultation_solde": "Gratuit",
          "e_banking_virement": "Gratuit",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "100,00",
          "prelevement_en_agence": "Gratuit",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "classique 450,00, premium 550,00, gold 650,00 / an",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "200",
          "retrait_intra_bancaire": "20",
          "retrait_inter_bancaire": "29.41",
          "creation_visa": "prepaye 2000,00, classique 4000,00, gold 6500,00, platinium 14000,00 / an",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "1000",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "03 mois client:25% banque : 75%, 06 mois client:45% banque : 55%, 12 mois client:59% banque : 41%",
          "depots_a_moyen_terme": "18 mois client:62% banque : 38%, 24 mois client:65% banque : 35%, 36 mois client:72% banque : 28%",
          "depots_a_long_terme": "48 mois client:80% banque : 20%, >=60 mois client:91% banque : 9%",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "5 000,00 / an",
          "moyen": "8 000,00 / an",
          "grand": "10 000,00 / an",
          "cautionnement": "10 000,00 / an"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "4 000,00 DA",
          "importation_domiciliation": "3 000,00 DA",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },
    },

    #####################################################################

    "entreprise": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "2 500,00 /Trim",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "1 000,00 /an",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit",
          "ouverture_compte_devise": "Gratuit",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "gratuit",
          "e_banking_consultation_solde": "Gratuit",
          "e_banking_virement": "50 en agence, 150 hors agence",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "100,00",
          "prelevement_en_agence": "Gratuit",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "classique 450,00, premium 550,00, gold 650,00 / an",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "200",
          "retrait_intra_bancaire": "20",
          "retrait_inter_bancaire": "29.41",
          "creation_visa": "prepaye 2000,00, classique 4000,00, gold 6500,00, platinium 14000,00 / an",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "1000",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "03 mois client:25% banque : 75%, 06 mois client:45% banque : 55%, 12 mois client:59% banque : 41%",
          "depots_a_moyen_terme": "18 mois client:62% banque : 38%, 24 mois client:65% banque : 35%, 36 mois client:72% banque : 28%",
          "depots_a_long_terme": "48 mois client:80% banque : 20%, >=60 mois client:91% banque : 9%",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "5 000,00 / an",
          "moyen": "8 000,00 / an",
          "grand": "10 000,00 / an",
          "cautionnement": "10 000,00 / an"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "4 000,00 DA",
          "importation_domiciliation": "3 000,00 DA",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },  
    }
}

# %% [markdown]
# ## arab plc

# %%
banks["ARAB BANK PLC ALGERIA"] = {
    
    "personnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "2600,00",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit",
          "ouverture_compte_devise": "Gratuit",
          "tenue_compte_devise": "Gratuit",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "gratuit",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "ooredoo 10,1/sms, djezzy 6,1/sms, mobilis 8,1/sms, international 16/sms",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "200,00",
          "prelevement_en_agence": "100,00",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "Gratuit",
          "retraits_hors_agence": "Gratuit",
          "payment_cheque_en_agence": "Gratuit",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "gratuit",
          "renouvelement_bank_card": "gratuit",
          "remplacement_bank_card": "550,00",
          "edition_code_confidentiel_bank_card": "550,00",
          "retrait_intra_bancaire": "20,00",
          "retrait_inter_bancaire": "29,41",
          "creation_visa": "gold Limite Minimale 1000 EUR - 5000da/an , platinium Limite Minimelc 5 000.00 EUR - 12000da/an, signature Limite Minimelc 10 000.00 EUR - 20000da/an",
          "renouvelement_visa": "gold 5000 da, platinium 12 000 da, signarture 20 000 da",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "1500",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "moins De 50 000,00 DZD - 0",
          "epargne_duree_taux_02": "De 50 000,00 DZD jusqu 500 000,00 DZD - 2%",
          "epargne_duree_taux_03": "De 500 001,00 DZD jusqu 2 000 000,00 DZD - 2.75%",
          "epargne_duree_taux_04": "De 2 000 001,00 DZD jusqu 10 000 000,00 DZD - 3%",
          "epargne_duree_taux_05": "supérieur à 10 000 000,00 DZD - 3.5%",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "6000",
          "moyen": "8000 / 10000",
          "grand": "12000",
          "cautionnement": "30000"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "professionnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "",
          "tenue_compte_cheque": "",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "",
          "virement_hors_agence": "",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "",
          "renouvelement_bank_card": "",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "",
          "retrait_intra_bancaire": "",
          "retrait_inter_bancaire": "",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "entreprise": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "gratuit",
          "tenue_compte_courant": "2500",
          "ouverture_compte_cheque": "gratuit",
          "tenue_compte_cheque": "",
          "ouverture_compte_epargne": "gratuit",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "gratuit",
          "tenue_compte_devise": "gratuit",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "gratuit",
          "versement_hors_agence": "gratuit",
          "virement_en_agence": "gratuit",
          "virement_hors_agence": "selon montat",
          "prelevement_en_agence": "50",
          "prelevement_hors_agence": "500",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "gratuit",
          "renouvelement_bank_card": "gratuit",
          "remplacement_bank_card": "2000",
          "edition_code_confidentiel_bank_card": "200",
          "retrait_intra_bancaire": "20",
          "retrait_inter_bancaire": "29.41",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "selon montat commençant 2000 DA pour <= 30000 USD/EUR",
          "virement_emis": "0.25% + 0.1% Com. B.A + 3000 frais swift",
          "exportation_domiciliation": "4000",
          "importation_domiciliation": "3000",
          "transfert_libre_prelevement_compte_dinars": "Marge de change 0.1%",
          "transfert_libre_prelevement_compte_devise": "3000 frais swift",
      },        
    }
}

# %% [markdown]
# ## cpa

# %%
banks["CREDIT POPULAIRE D ALGERIE - CPA"] = {
    
    "personnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "200DA",
          "ouverture_compte_cheque": "",
          "tenue_compte_cheque": "300DA",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "50DA/mois/compte",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "Gratuit(banque) 50DA(agence)",
          "virement_hors_agence": "100 DA",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit",
          "renouvelement_bank_card": "Gratuit",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "Gratuit",
          "retrait_intra_bancaire": "25 DA",
          "retrait_inter_bancaire": "40 DA",
          "creation_visa": "Classique 6000DA/an, Gold 9000DA/an",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "epargnant: 5.75%, sinon 6.25%",
          "credit_moyen_terme_taux": "epargnant: 5.75%, sinon 6.25%",
          "credit_long_terme_taux": "epargnant: 5.75%, sinon 6.25%",
          "options_possibles": "Vehicule de tourisme 5000DA, autre 4000 DA"
      },

      "placement": {
          "depots_a_court_terme": "03_06 mois: 1.25%",
          "depots_a_moyen_terme": "18-24 mois: 2.00%",
          "depots_a_long_terme": "+60mois 4.00%",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "3000 DA/an",
          "moyen": "4000 DA/an",
          "grand": "6000 DA/an",
          "cautionnement": "6000 DA"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "professionnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "1500 DA",
          "ouverture_compte_cheque": "",
          "tenue_compte_cheque": "300 DA",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "50DA/mois/compte",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "",
          "versement_hors_agence": "",
          "virement_en_agence": "50 DA",
          "virement_hors_agence": "100 DA",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit",
          "renouvelement_bank_card": "Gratuit",
          "remplacement_bank_card": "Gratuit",
          "edition_code_confidentiel_bank_card": "Gratuit",
          "retrait_intra_bancaire": "25 DA",
          "retrait_inter_bancaire": "40 DA",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "3-5 ans: 8-9 %",
          "credit_moyen_terme_taux": "5-7 ans: 9-10%",
          "credit_long_terme_taux": "7-15 ans: 10-11%",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "03-06 mois: 1.25%",
          "depots_a_moyen_terme": "18-24 mois: 2.0%",
          "depots_a_long_terme": "+60 mois: 4.0%",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "3000DA/dossier",
          "importation_domiciliation": "3000DA/dossier",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "entreprise": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "1500 DA",
          "ouverture_compte_cheque": "",
          "tenue_compte_cheque": "300 DA",
          "ouverture_compte_epargne": "",
          "tenue_compte_epargne": "",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "50DA/mois/compte",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "50 DA",
          "virement_hors_agence": "100 DA",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit",
          "renouvelement_bank_card": "Gratuit",
          "remplacement_bank_card": "Gratuit",
          "edition_code_confidentiel_bank_card": "Gratuit",
          "retrait_intra_bancaire": "25 DA",
          "retrait_inter_bancaire": "40 DA",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "3-5 ans: 8-9%",
          "credit_moyen_terme_taux": "5-7 ans: 9-10%",
          "credit_long_terme_taux": "7-15 ans: 10-11%",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "3-6 mois: 1.25%",
          "depots_a_moyen_terme": "18-24 mois: 2.00%",
          "depots_a_long_terme": "+60 mois: 4.0%",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "3000 DA/dossier",
          "importation_domiciliation": "3000 DA/dossier",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    }
}

# %% [markdown]
# ## abc

# %%
banks["ARAB BANKING CORPORATION ALGERIE - ABC"] = {
    
    "personnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "600 DZD/Trim",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit (montant initial : 1000 DZD)",
          "ouverture_compte_devise": "Gratuit",
          "tenue_compte_devise": "Gratuit",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "Gratuit",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "100 DZD/mois",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "Selon montat",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "250 DZD",
          "retraits_hors_agence": "250 DZD",
          "payment_cheque_en_agence": "100 DZD",
          "payment_cheque_hors_agence": "100 DZD",
          "vente_devise": "Gratuit",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit: 850DZD/an(gold) 650DZD/an(classique)",
          "renouvelement_bank_card": "Gratuit",
          "remplacement_bank_card": "Gratuit",
          "edition_code_confidentiel_bank_card": "250 DZD",
          "retrait_intra_bancaire": "Gratuit",
          "retrait_inter_bancaire": "35 DZD",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "TRD+3% An",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "TRD+2%",
          "credit_long_terme_taux": "TRD+2%",
          "options_possibles": "Moumkin, Carousty, Soukna"
      },

      "placement": {
          "depots_a_court_terme": "3-6 mois: TRC-0.50%",
          "depots_a_moyen_terme": "12-24 mois: TRC",
          "depots_a_long_terme": "+48 mois: TRC+1%",
      },

      "epargne": {
          "epargne_duree_taux_01": "Jusqu a 10 KDZD : 0%",
          "epargne_duree_taux_02": "De 10 KDZD jusqu 1 000 000 DZD : TRC-0,50%",
          "epargne_duree_taux_03": "De 1 000 000 DZD Jusqu 5 000 000 DZD : TRC+1,00%",
          "epargne_duree_taux_04": "De 5 000 000 DZD jusqu 20 000 000 DZD : TRC+2,00%",
          "epargne_duree_taux_05": "Supérieur à 20 000 000 DZD : TRC+3,00%",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "5 000 DZD",
          "moyen": "10 000 DZD",
          "grand": "20 000 DZD",
          "cautionnement": "10 000 DZD"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "en agence: 1 000 DZD, hors: 2 000 DZD +frais envoi",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "3 000 DZD",
          "importation_domiciliation": "3 000 DZD",
          "transfert_libre_prelevement_compte_dinars": "Cours Vente de la banque à la date du règlement",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "professionnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "2000 DZD/Trim.",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "600 DZD/Trim",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit (montant initial : 1000 DZD)",
          "ouverture_compte_devise": "Gratuit",
          "tenue_compte_devise": "Gratuit",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "800 DZD",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "500 DZD/mois",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "Selon montat",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "250 DZD",
          "retraits_hors_agence": "250 DZD",
          "payment_cheque_en_agence": "100 DZD",
          "payment_cheque_hors_agence": "100 DZD",
          "vente_devise": "Gratuit",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit: 850DZD/an(gold) 650DZD/an(classique)",
          "renouvelement_bank_card": "Gratuit",
          "remplacement_bank_card": "Gratuit",
          "edition_code_confidentiel_bank_card": "250 DZD",
          "retrait_intra_bancaire": "Gratuit",
          "retrait_inter_bancaire": "35 DZD",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "TRD+3% An",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "TRD+2%",
          "credit_long_terme_taux": "TRD+2%",
          "options_possibles": "Moumkin, Carousty, Soukna"
      },

      "placement": {
          "depots_a_court_terme": "3-6 mois: TRC-0.50%",
          "depots_a_moyen_terme": "12-24 mois: TRC",
          "depots_a_long_terme": "+48 mois: TRC+1%",
      },

      "epargne": {
          "epargne_duree_taux_01": "Jusqu 10 KDZD : 0%",
          "epargne_duree_taux_02": "De 10 KDZD jusqu 1 000 000 DZD : TRC-0,50%",
          "epargne_duree_taux_03": "De 1 000 000 DZD Jusqu 5 000 000 DZD : TRC+1,00%",
          "epargne_duree_taux_04": "De 5 000 000 DZD jusqu 20 000 000 DZD : TRC+2,00%",
          "epargne_duree_taux_05": "Supérieur à 20 000 000 DZD : TRC+3,00%",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "5 000 DZD",
          "moyen": "10 000 DZD",
          "grand": "20 000 DZD",
          "cautionnement": "10 000 DZD"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "en agence: 1 000 DZD, hors: 2 000 DZD +frais envoi",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "3 000 DZD",
          "importation_domiciliation": "3 000 DZD",
          "transfert_libre_prelevement_compte_dinars": "Cours Vente de la banque à la date du règlement",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "entreprise": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "Gratuit",
          "tenue_compte_courant": "2500 DZD/Trim",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "600 DZD/Trim",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit (montant initial : 1000 DZD)",
          "ouverture_compte_devise": "Gratuit",
          "tenue_compte_devise": "Gratuit",
          "fermeture_de_compte": ""
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "1000 DZD",
          "e_banking_consultation_solde": "",
          "e_banking_virement": "",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "Selon montat",
          "prelevement_en_agence": "",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "250 DZD",
          "retraits_hors_agence": "250 DZD",
          "payment_cheque_en_agence": "100 DZD",
          "payment_cheque_hors_agence": "100 DZD",
          "vente_devise": "Gratuit",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit: 850DZD/an(gold) 650DZD/an(classique)",
          "renouvelement_bank_card": "Gratuit",
          "remplacement_bank_card": "Gratuit",
          "edition_code_confidentiel_bank_card": "250 DZD",
          "retrait_intra_bancaire": "Gratuit",
          "retrait_inter_bancaire": "35 DZD",
          "creation_visa": "",
          "renouvelement_visa": "",
          "remplacement_visa": "",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "TRD+3% An",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "TRD+2%",
          "credit_long_terme_taux": "TRD+2%",
          "options_possibles": "Moumkin, Carousty, Soukna"
      },

      "placement": {
          "depots_a_court_terme": "3-6 mois: TRC-0.50%",
          "depots_a_moyen_terme": "12-24 mois: TRC",
          "depots_a_long_terme": "+48 mois: TRC+1%",
      },

      "epargne": {
          "epargne_duree_taux_01": "Jusqu 10 KDZD : 0%",
          "epargne_duree_taux_02": "De 10 KDZD jusqu 1 000 000 DZD : TRC-0,50%",
          "epargne_duree_taux_03": "De 1 000 000 DZD Jusqu 5 000 000 DZD : TRC+1,00%",
          "epargne_duree_taux_04": "De 5 000 000 DZD jusqu 20 000 000 DZD : TRC+2,00%",
          "epargne_duree_taux_05": "Supérieur à 20 000 000 DZD : TRC+3,00%",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "5 000 DZD",
          "moyen": "10 000 DZD",
          "grand": "20 000 DZD",
          "cautionnement": "10 000 DZD"
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "en agence: 1 000 DZD, hors: 2 000 DZD +frais envoi",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "3 000 DZD",
          "importation_domiciliation": "3 000 DZD",
          "transfert_libre_prelevement_compte_dinars": "Cours Vente de la banque à la date du règlement",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },
}

# %% [markdown]
# ## natixis

# %%
banks["NATIXIS BANQUE"] = {
    
    "personnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "375 DA/Trim",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "Gratuit",
          "e_banking_consultation_solde": "Gratuit",
          "e_banking_virement": "Gratuit",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "100 DA",
          "prelevement_en_agence": "Gratuit",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "par cheque : Gratuit",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "60 DA",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit",
          "renouvelement_bank_card": "1 190 DA ",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "500 DA",
          "retrait_intra_bancaire": "Gratuit",
          "retrait_inter_bancaire": "Gratuit",
          "creation_visa": "First: 5 000 DA, Gold: 14 000 DA, Platinium: 35 000 DA",
          "renouvelement_visa": "First: 5 000 DA, Gold: 14 000 DA, Platinium: 35 000 DA",
          "remplacement_visa": "First: 5 000 DA, Gold: 14 000 DA, Platinium: 35 000 DA",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "professionnel": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "375 DA/Trim",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "Gratuit",
          "e_banking_consultation_solde": "Gratuit",
          "e_banking_virement": "Gratuit",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "100 DA",
          "prelevement_en_agence": "Gratuit",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "par cheque : Gratuit",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "60 DA",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit",
          "renouvelement_bank_card": "1 190 DA ",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "500 DA",
          "retrait_intra_bancaire": "Gratuit",
          "retrait_inter_bancaire": "Gratuit",
          "creation_visa": "First: 5 000 DA, Gold: 14 000 DA, Platinium: 35 000 DA",
          "renouvelement_visa": "First: 5 000 DA, Gold: 14 000 DA, Platinium: 35 000 DA",
          "remplacement_visa": "First: 5 000 DA, Gold: 14 000 DA, Platinium: 35 000 DA",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },

    #####################################################################

    "entreprise": {
        
      "gestion_de_compte": {
          "ouverture_compte_courant": "",
          "tenue_compte_courant": "",
          "ouverture_compte_cheque": "Gratuit",
          "tenue_compte_cheque": "375 DA/Trim",
          "ouverture_compte_epargne": "Gratuit",
          "tenue_compte_epargne": "Gratuit",
          "ouverture_compte_devise": "",
          "tenue_compte_devise": "",
          "fermeture_de_compte": "Gratuit"
      },

      "gestion_a_distance": {
          "e_banking_abonnement": "Gratuit",
          "e_banking_consultation_solde": "Gratuit",
          "e_banking_virement": "Gratuit",
          "e_banking_paiment": "",
          "sms_banking_abonnement": "",
          "sms_banking_virement_en_agence": "",
          "sms_banking_virement_hors_agence": "",
          "service_contact": "",
      },

      "option_de_payment": {
          "versement_en_agence": "Gratuit",
          "versement_hors_agence": "Gratuit",
          "virement_en_agence": "Gratuit",
          "virement_hors_agence": "100 DA",
          "prelevement_en_agence": "Gratuit",
          "prelevement_hors_agence": "",
          "retraits_en_agence": "par cheque : Gratuit",
          "retraits_hors_agence": "",
          "payment_cheque_en_agence": "60 DA",
          "payment_cheque_hors_agence": "",
          "vente_devise": "",
          "achat_devise": ""
      },

      "moyens_de_payment": {
          "creation_bank_card": "Gratuit",
          "renouvelement_bank_card": "1 190 DA ",
          "remplacement_bank_card": "",
          "edition_code_confidentiel_bank_card": "500 DA",
          "retrait_intra_bancaire": "Gratuit",
          "retrait_inter_bancaire": "Gratuit",
          "creation_visa": "First: 5 000 DA, Gold: 14 000 DA, Platinium: 35 000 DA",
          "renouvelement_visa": "First: 5 000 DA, Gold: 14 000 DA, Platinium: 35 000 DA",
          "remplacement_visa": "First: 5 000 DA, Gold: 14 000 DA, Platinium: 35 000 DA",
          "edition_code_confidentiel_visa": "",
      },

      "prets_et_credits": {
          "decouvert_duree": "",
          "decouvert_taux": "",
          "credit_court_terme_taux": "",
          "credit_moyen_terme_taux": "",
          "credit_long_terme_taux": "",
          "options_possibles": ""
      },

      "placement": {
          "depots_a_court_terme": "",
          "depots_a_moyen_terme": "",
          "depots_a_long_terme": "",
      },

      "epargne": {
          "epargne_duree_taux_01": "",
          "epargne_duree_taux_02": "",
          "epargne_duree_taux_03": "",
          "epargne_duree_taux_04": "",
          "epargne_duree_taux_05": "",
          "epargne_duree_taux_06": "",
          "epargne_duree_taux_07": "",
          "epargne_duree_taux_08": "",
          "epargne_duree_taux_09": "",
          "epargne_duree_taux_10": "",
      },

      "coffre_fort": {
          "petit": "",
          "moyen": "",
          "grand": "",
          "cautionnement": ""
      },

      "financement_externe": {
          "encaissement_cheque_etranger": "",
          "virement_recu": "",
          "virement_emis": "",
          "exportation_domiciliation": "",
          "importation_domiciliation": "",
          "transfert_libre_prelevement_compte_dinars": "",
          "transfert_libre_prelevement_compte_devise": "",
      },        
    },
}

# %% [markdown]
# # IDs

# %%
bank_ids = {
          "BANQUE NATIONALE D ALGERIE - BNA": 186,
          "BANQUE DE L AGRICULTURE ET DU DEVELOPPEMENT RURAL - BADR": 278,
          "BANQUE DE DEVELOPPEMENT LOCAL - BDL": 736,
          "CREDIT POPULAIRE D ALGERIE - CPA": 469,
          "ARAB BANKING CORPORATION ALGERIE - ABC": 214,
          "NATIXIS BANQUE": 353,
          "SOCIETE GENERALE ALGERIE": 876,
          "ARAB BANK PLC ALGERIA": 175,
          "B.N.P.-PARIBAS EL DJAZAIR": 366,
          "TRUST BANK ALGERIA": 2037,
          "GULF BANK ALGERIA": 339345,
          "THE HOUSING BANK FOR TRADE AND FINANCE-ALGERIA": 45378,
          "FRANSABANK EL-DJAZAIR": 2437,
          "CREDIT AGRICOLE CORPORATE ET INVESTISSEMENT BANK - ALGERIE": 87258,
          "AL SALAM BANK - ALGERIA - SPA": 205,
         }

# %% [markdown]
# # Sheets

# %%
import pandas as pd

# %%
categories = template["personnel"].keys()
categories
# Out:
# dict_keys(['gestion_de_compte', 'gestion_a_distance', 'option_de_payment', 'moyens_de_payment', 'prets_et_credits', 'placement', 'epargne', 'coffre_fort', 'financement_externe'])

# %%
for category in categories:
  print(f"Making {category} file")

  columns = {}
  columns["id_banque"] = []
  columns["nom_banque"] = []
  columns["type"] = []
  for prestation in template["personnel"][category].keys():
    columns[prestation] = []

  for banque in banks.keys():
    #print(f"-> currently with {banque}")
    for type in types:
      #print(f"----> the type {type}")
      columns["id_banque"].append(bank_ids[banque])
      columns["nom_banque"].append(banque)
      columns["type"].append(type)

      for prestation in banks[banque][type][category].keys():
        #print(f"--------------> inserting {prestation}")
        columns[prestation].append(banks[banque][type][category][prestation])
        # if prestation == "payment_cheque_hors_agence":
        #   print(f"{banque} {type} {category} {prestation}")
        #   print(f"------currently column shape = {len(columns[prestation])}")

  path = f"./tables/{category}.csv"

  # for name in columns.keys():
  #   print(f"columns {name} of shape {len(columns[name])}")
  # print(columns.keys())
  df = pd.DataFrame(columns, columns = columns.keys())

  df.to_csv(path, index=False)
# Out:
# Making gestion_de_compte file
# Making gestion_a_distance file
# Making option_de_payment file
# Making moyens_de_payment file
# Making prets_et_credits file
# Making placement file
# Making epargne file
# Making coffre_fort file
# Making financement_externe file
